# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/books_rating.csv')
df.head()
# Out:
#            Id                           Title  Price         User_id  \
# 0  1882931173  Its Only Art If Its Well Hung!    NaN   AVCGYZL8FQQTD
# 1  0826414346        Dr. Seuss: American Icon    NaN  A30TK6U7DNS82R
# 2  0826414346        Dr. Seuss: American Icon    NaN  A3UH4UZ4RSVO82
# 3  0826414346        Dr. Seuss: American Icon    NaN  A2MVUWT453QH61
# 4  0826414346        Dr. Seuss: American Icon    NaN  A22X4XUPKF66MR
#
#                           profileName review/helpfulness  review/score  \
# 0               Jim of Oz "jim-of-oz"                7/7           4.0
# 1                       Kevin Killian              10/10           5.0
# 2                        John Granger              10/11           5.0
# 3  Roy E. Perry "amateur philosopher"                7/7           4.0
# 4     D. H. Richards "ninthwavestore"                3/3           4.0
#
#    review/time                                   review/summary  \
# 0    940636800           Nice collection of Julie Strain images
# 1   1095724800                                Really Enjoyed It
# 2   1078790400  Essential for every personal and Public Library
# 3   1090713600  Phlip Nel gives silly Seuss a serious treatment
# 4   1107993600                           Good academic overview
#
#                                          review/text
# 0  This is only for Julie Strain fans. It's a col...
# 1  I don't care much for Dr. Seuss but after read...
# 2  If people become the books they read and if "t...
# 3  Theodore Seuss Geisel (1904-1991), aka &quot;D...
# 4  Philip Nel - Dr. Seuss: American IconThis is b...

# %%
fiction_df = pd.read_csv('../data/books.csv')
fiction_df.head()
# Out:
#                                                Title  \
# 0                   Nostromo: A tale of the seaboard
# 1  Alice's adventures in Wonderland and Through t...
# 2                                Bride of a Stranger
# 3                                             Yonder
# 4                       Rushing to Paradise: A Novel
#
#                                             synopsis  \
# 0  Reproduction of the original: Nostromo: A Tale...
# 1  All the "muchness" of Wonderland captured in o...
# 2  Claire is too innocent to suspect that her mar...
# 3  Max Raymond, a weak Christian saxophonist, is ...
# 4  J.G. Ballard – author of Crash and Empire of t...
#
#                                             coverImg  yearPublished  \
# 0  http://books.google.com/books/content?id=jORvD...           2018
# 1  http://books.google.com/books/content?id=didZD...           2016
# 2  http://books.google.com/books/content?id=IV4wt...           2000
# 3  http://books.google.com/books/content?id=xJ4Ct...           2002
# 4  http://books.google.com/books/content?id=Pdzpy...           2012
#
#                                             infoLink  avgRating  authorId  \
# 0  http://books.google.com/books?id=jORvDwAAQBAJ&...          0       212
# 1  https://play.google.com/store/books/details?id...          0       254
# 2  http://books.google.com/books?id=IV4wtAEACAAJ&...          0       189
# 3  http://books.google.nl/books?id=xJ4CtHDRB5sC&d...          0        37
# 4  https://play.google.com/store/books/details?id...          0       162
#
#    publisherId  genreId
# 0           34        6
# 1          164        3
# 2           65        8
# 3           82        8
# 4           91        6

# %%
merged_df = pd.merge(fiction_df, df, how='left')
merged_df = merged_df[['Title',  'profileName', 'review/score',  'review/text']]
merged_df.dropna(axis=0, inplace=True)
print(f'{merged_df.shape[0]} reviews')
merged_df.head(10)
# Out:
# 23611 reviews
#                                Title                     profileName  \
# 0   Nostromo: A tale of the seaboard  scutler@nimbus.ocis.temple.edu
# 1   Nostromo: A tale of the seaboard                           Joe W
# 2   Nostromo: A tale of the seaboard         Schmerguls "schmerguls"
# 3   Nostromo: A tale of the seaboard    Joseph H Pierre "Joe Pierre"
# 4   Nostromo: A tale of the seaboard      C. M Mills "Michael Mills"
# 5   Nostromo: A tale of the seaboard           H. Schneider "Hermit"
# 7   Nostromo: A tale of the seaboard                       C. Garvin
# 8   Nostromo: A tale of the seaboard                  Kristen Walter
# 9   Nostromo: A tale of the seaboard                       gammyraye
# 10  Nostromo: A tale of the seaboard                Eugene G. Barnes
#
#     review/score                                        review/text
# 0            5.0  This is a bitter and brutal book. Conrad is no...
# 1            5.0  "Nostromo" is arguably Conrad's best novel. Th...
# 2            5.0  I found Nostromo sslow going at first, but thi...
# 3            5.0  Joseph Conrad, the author of this story, was b...
# 4            5.0  Nostromo is one of the greatest novels of the ...
# 5            5.0  `Nostromo' was one of Conrad's most political ...
# 7            2.0  Look, I'm a patient reader. I make a commitmen...
# 8            5.0  Wonderfully rich language from Conrad. Charact...
# 9            5.0  First, this is not the book I expected from re...
# 10           3.0  Back when &quot;Nostromo&quot; first came out,...

# %%
reviewerCounts = merged_df.groupby(by='profileName')['profileName'].count().sort_values(ascending=False)
print(f'{reviewerCounts.shape[0]} reviewers')
reviewerCounts[reviewerCounts >= 20]
# Out:
# 16007 reviewers
# profileName
# Harriet Klausner                    64
# A Customer                          37
# Blue Tyson "- Research Finished"    36
# S. Schwartz "romonko"               26
# E. A Solinas "ea_solinas"           23
# Lawyeraau                           22
# Avid Reader                         21
# Bookreporter                        20
# Name: profileName, dtype: int64

# %% [markdown]
# Pick a couple of obvious pseudnymous reviewers. Turns out there are a lot of duplicates, which suggests names are fake anyway. So remove duplicates of Title and profileName combinations.

# %%
reviews_df = merged_df[merged_df['profileName'].isin(['A Customer', 'Avid Reader'])]
reviews_df.drop_duplicates(subset=['Title', 'profileName'], inplace=True)
reviews_df.rename(columns={'review/score': 'rating', 'review/text': 'review'}, inplace=True)
reviews_df['rating'] = reviews_df['rating'].astype(int)
print(f'{reviews_df.shape[0]} reviews')
reviews_df
# Out:
# 41 reviews
#                                                    Title  profileName  rating  \
# 393    Alice's adventures in Wonderland and Through t...   A Customer       5
# 470                                        Night And Day   A Customer       1
# 1111                          The Other Side Of Midnight  Avid Reader       5
# 1485                                       Last Precinct   A Customer       3
# 2000                                    Lover's Talisman  Avid Reader       5
# 2205                          The Fellowship of the Ring   A Customer       4
# 3811                                       Maggie's Hope   A Customer       5
# 4149                                   The Intelligencer  Avid Reader       2
# 4424                                        Oceans Apart   A Customer       5
# 7864   Something To Kill For: When It Comes To Garage...  Avid Reader       4
# 7915                            Silence in Hanover Close   A Customer       5
# 9275             Heart of Darkness and the Secret Sharer   A Customer       1
# 10997                                Island of the Swans   A Customer       5
# 11975                              Playing for the Ashes  Avid Reader       5
# 12253                                      One Last Time   A Customer       5
# 12772  Evelina, or, A young lady's entrance into the ...  Avid Reader       5
# 12997                                     Shadow Puppets   A Customer       5
# 13878                            Beautiful Lies: A Novel   A Customer       3
# 13950     The Silver Hand (The Song of Albion, Book Two)  Avid Reader       4
# 14162                FROM A BUICK 8 (True first edition)   A Customer       5
# 14954                                   Barney's Version   A Customer       5
# 15963                                    Of Mice And Men   A Customer       5
# 17668                                       Cat's Cradle   A Customer       5
# 19419                                              Texas  Avid Reader       4
# 19487                                     Watership Down   A Customer       5
# 20648                                    Once a Princess   A Customer       4
# 20774                            The Vision of Emma Blau  Avid Reader       5
# 21970                                           Moloka'i  Avid Reader       5
# 22598                               PYRAMIDS (DISCWORLD)   A Customer       5
# 23145                                         Odd Thomas   A Customer       5
# 23423                     Devil's Bride (Cynster Novels)  Avid Reader       2
# 23428                     Devil's Bride (Cynster Novels)   A Customer       1
# 24328                                           Tea Rose  Avid Reader       5
# 25572                                     Satanic Verses   A Customer       5
# 25912                    Persuader (Jack Reacher, No. 7)   A Customer       5
# 25958                    Persuader (Jack Reacher, No. 7)  Avid Reader       5
# 26489                                    Point of origin   A Customer       3
# 27152                                            Evelina  Avid Reader       5
# 28034                      The last temptation of Christ  Avid Reader       5
# 28778                                      Closed Circle   A Customer       4
# 28869                                      The Big Sleep  Avid Reader       5
#
#                                                   review
# 393    Find some children anywhere you can and read t...
# 470    a complete wast of time and money a complete w...
# 1111   This book may never have won the Pultizer Priz...
# 1485   This book was better than the last few Scarpet...
# 2000   Exiting new author Ashleigh Raine from the Pub...
# 2205   This is a great book, but i think it is the mo...
# 3811   Maggie's Hope is a great summer read, speciall...
# 4149   Based on the reviews, I thought this book woul...
# 4424   wow this was a wonderful story. it made me cry...
# 7864   I picked this up at the library the other day,...
# 7915   I have only read 2 books by Anne - &quot;Farri...
# 9275   there goes 5 hours of my life i will never get...
# 10997  I am thrilled that Ciji Ware's Island of the S...
# 11975  I have read all the Elizabeth George mysteries...
# 12253  &quot;One Last Time&quot; was an amazing book....
# 12772  This book is fantastic! It is so entertaining ...
# 12997  Just a masterpiece by Orson Scott Card. One of...
# 13878  When I staerted reading this book I really cou...
# 13950  After the somewhat disappointing first book in...
# 14162  Fantastic! The best King ever! Buy it now, bec...
# 14954  I really enjoyed this book. It is well written...
# 15963  This short book is a very quick read, yet is a...
# 17668  This book was pure comic genius using dark iro...
# 19419  This is a good overview of Texas history. It w...
# 19487  I like this book very much because it was fill...
# 20648  Overall, this is a wonderful book. I love the ...
# 20774  When I read Ursula Hegi, I pack my bags in ord...
# 21970  Moloka'i is an incredible historical fiction n...
# 22598  I've decided he's too good and too prolific fo...
# 23145  I am a fourteen year old boy and i read ALOT o...
# 23423  This is the second Stephanie Laurens book I've...
# 23428  WARNING! This book suffers from being overly d...
# 24328  I have to admit that I've not read The Tea Ros...
# 25572  All the notoreity and religious bigotry arouse...
# 25912  Having never read a Reacher novel before I was...
# 25958  Again, Lee Child weaves a story that makes me ...
# 26489  I found the book to be considerably less enjoy...
# 27152  This book is fantastic! It is so entertaining ...
# 28034  Kazanzakis portrays a Jesus with whom we can r...
# 28778  I have been a book addict since little and spe...
# 28869  This is my all-time favorite book. You can rea...

# %%
reviews_df[['profileName', 'review', 'rating']].to_csv('../data/reviews.csv', index=False)
